# %% [markdown]
# ### Overview list containing all variables

# %%
import pyaerocom as pya
import pandas as pd
pd.set_option('display.max_rows', 500)
table = pya.variable.all_vars_to_dataframe()
# Out:
# Init data paths for lustre
# 0.026346921920776367 s

# %%
table
# Out:
#                   Name                                      Standard name  \
# 0              DEFAULT                                               None
# 1             od550aer  atmosphere_optical_thickness_due_to_ambient_ae...
# 2          od550lt1aer                                               None
# 3          od550gt1aer                                               None
# 4            abs550aer  atmosphere_absorption_optical_thickness_due_to...
# 5             od440aer  atmosphere_optical_thickness_due_to_ambient_ae...
# 6            abs440aer  atmosphere_absorption_optical_thickness_due_to...
# 7             ec550aer  volume_extinction_coefficient_in_air_due_to_am...
# 8             ec532aer  volume_extinction_coefficient_in_air_due_to_am...
# 9          scatc550aer                                               None
# 10      scatc550lt1aer                                               None
# 11        bscatc550aer                                               None
# ...
